# %%
from pymongo import MongoClient # this lets us connect to MongoDB
import pprint # this lets us print our MongoDB documents nicely

# %%
# the connection uri to our course cluster
import certifi
ca = certifi.where()

# Replace XXX with your cluster url
url = 'XXX'

client = MongoClient(url, tlsCAFile=ca)

# %%
# the trips collection on the citibike database
trips = client.citibike.trips

# %%
# find all trips between 5 and 10 minutes in duration that start at station 216
query = {"tripduration":{"$gte":5000,"$lt":10000},"start station id":216}

# only return the bikeid, tripduration, and _id (displayed by default)
projection = {"bikeid": 1, "tripduration": 1}

# %%
# print all of the trips
for doc in trips.find(query, projection):
    print(doc)
# Out:
# {'_id': ObjectId('572bb8262b288919b68ce62f'), 'tripduration': 5294, 'bikeid': 15947}
# {'_id': ObjectId('572bb8262b288919b68ce62b'), 'tripduration': 5296, 'bikeid': 23539}
# {'_id': ObjectId('572bb8282b288919b68e2f73'), 'tripduration': 6753, 'bikeid': 14936}
# {'_id': ObjectId('572bb8362b288919b6957859'), 'tripduration': 7532, 'bikeid': 15996}
# {'_id': ObjectId('572bb8362b288919b6957856'), 'tripduration': 7528, 'bikeid': 22463}
# {'_id': ObjectId('572bb83c2b288919b698a8a5'), 'tripduration': 5758, 'bikeid': 20123}
# {'_id': ObjectId('572bb83c2b288919b698a8a9'), 'tripduration': 5760, 'bikeid': 15904}
# {'_id': ObjectId('572bb8432b288919b69c213a'), 'tripduration': 5293, 'bikeid': 19549}
# {'_id': ObjectId('572bb8432b288919b69c211e'), 'tripduration': 6318, 'bikeid': 16960}
# {'_id': ObjectId('572bb8432b288919b69c2192'), 'tripduration': 8778, 'bikeid': 18922}
# {'_id': ObjectId('572bb8432b288919b69c2193'), 'tripduration': 8777, 'bikeid': 17275}
